# %% [markdown]
# # PDF -> TXT 파일 전환

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     133   if ephemeral:
#     134     _message.blocking_request(
# --> 135         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     136
#     137   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
# !pip install pdfminer.six
# Out:
# ...
#      |████████████████████████████████| 5.6 MB 23.2 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 39.7 MB/s
# ...

# %%
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

output_string = StringIO()
with open('/content/drive/MyDrive/Colab Notebooks/dacon/data/기호_1 공약.pdf', 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)

# %%
with open('/content/drive/MyDrive/Colab Notebooks/dacon/data/result/기호_1 공약.txt', mode='w', encoding='UTF-8') as output:
    output.write(output_string.getvalue())

# %%
# !pip install pdfplumber
# Out:
# ...
#      |████████████████████████████████| 46 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 31.2 MB/s
# ...
#      |████████████████████████████████| 139 kB 69.9 MB/s
# ...
#   Created wheel for pdfplumber: filename=pdfplumber-0.6.0-py3-none-any.whl size=33688 sha256=d4f488da141d6b74f8f23749b2963478e4b8c929819056589f35a53ffb0339d0
#   Stored in directory: /root/.cache/pip/wheels/58/56/fe/2e93d842ffa9ea97746c1ab253d43502ed61c0689361a0224e
# Successfully built pdfplumber
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
import pdfplumber

path = '/content/drive/MyDrive/Colab Notebooks/dacon/data/기호_1 공약'
sample = f'{path}.pdf'

pdf = pdfplumber.open(sample)


script = ''

for page in range(len(pdf.pages)):
    text =  pdf.pages[page].extract_text()
    script += text

# %%
with open('/content/drive/MyDrive/Colab Notebooks/dacon/data/result/기호_1 공약_other.txt', mode='w', encoding='UTF-8') as output:
    output.write(script)

# %%
import pdfplumber
for num in range(1,15):
  path = f'/content/drive/MyDrive/Colab Notebooks/dacon/data/기호_{num} 공약.pdf'
  pdf = pdfplumber.open(path)
  script = ''
  for page in range(len(pdf.pages)):
    text =  pdf.pages[page].extract_text()
    script += text
    with open(f'/content/drive/MyDrive/Colab Notebooks/dacon/data/result/기호_{num} 공약.txt', mode='w', encoding='UTF-8') as output:
      output.write(script)
